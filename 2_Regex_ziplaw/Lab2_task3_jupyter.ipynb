# %% [markdown]
# **Name: Aditya Sharma**
#
# **Roll: 2022BCD0035**

# %% [markdown]
# # ***English***

# %%
import requests
import re
import matplotlib.pyplot as plt
from collections import Counter
import numpy as np

# %%
url = "https://www.gutenberg.org/cache/epub/100/pg100.txt"
text = requests.get(url).text

# %%
words = re.findall(r"\b[a-z]+\b", text.lower())
print(words[:50])
# Out:
# ['the', 'project', 'gutenberg', 'ebook', 'of', 'the', 'complete', 'works', 'of', 'william', 'shakespeare', 'this', 'ebook', 'is', 'for', 'the', 'use', 'of', 'anyone', 'anywhere', 'in', 'the', 'united', 'states', 'and', 'most', 'other', 'parts', 'of', 'the', 'world', 'at', 'no', 'cost', 'and', 'with', 'almost', 'no', 'restrictions', 'whatsoever', 'you', 'may', 'copy', 'it', 'give', 'it', 'away', 'or', 're', 'use']

# %%
word_counts = Counter(words)
most_common = word_counts.most_common()
print(most_common[:10])
# Out:
# [('the', 30526), ('and', 28566), ('i', 24188), ('to', 20844), ('of', 18882), ('a', 16494), ('you', 14728), ('my', 13201), ('in', 12585), ('that', 12282)]

# %%
frequencies = np.array([freq for word, freq in most_common])
print(frequencies)
# Out:
# [30526 28566 24188 ...     1     1     1]

# %%
ranks = np.arange(1, len(most_common)+1)
plt.figure(figsize=(8,6))
plt.loglog(ranks, frequencies, marker=".")
plt.title("Zipf's Law Verification (The Complete Works of William Shakespeare)")
plt.xlabel("Rank of word")
plt.ylabel("Frequency of word")
plt.grid(True)
plt.show()

# %% [markdown]
# # **Hindi**

# %%
url = "https://hi.wikipedia.org/wiki/%E0%A4%B8%E0%A4%9A%E0%A4%BF%E0%A4%A8_%E0%A4%A4%E0%A5%87%E0%A4%82%E0%A4%A6%E0%A5%81%E0%A4%B2%E0%A4%95%E0%A4%B0"  #Sachin Tendulkar
text_hi = requests.get(url).text

# %%
words_hi = re.findall(r"[\u0900-\u097F]+", text_hi)
print(words_hi[:50])
# Out:
# ['सचिन', 'तेंदुलकर', 'विकिपीडिया', '०', '१', '२', '३', '४', '५', '६', '७', '८', '९', 'जनवरी', 'फ़रवरी', 'मार्च', 'अप्रैल', 'मई', 'जून', 'जुलाई', 'अगस्त', 'सितंबर', 'अक्टूबर', 'नवम्बर', 'दिसम्बर', 'सचिन', 'तेंदुलकर', 'सचिन', 'तेंदुलकर', 'सुधार', 'योग्य', 'सभी', 'लेख', 'लेख', 'जिनमें', 'जून', 'से', 'मृत', 'कड़ियाँ', 'हैं', 'मृत', 'कड़ियों', 'वाले', 'लेख', 'वेबआर्काइव', 'टेम्पलेट', 'वेबैक', 'कड़ियाँ', 'सभी', 'लेख']

# %%
word_counts_hi = Counter(words_hi)
most_common_hi = word_counts_hi.most_common()
print(most_common_hi[:10])
# Out:
# [('के', 240), ('में', 193), ('क्रिकेट', 136), ('से', 110), ('सचिन', 101), ('तेंदुलकर', 96), ('की', 87), ('को', 65), ('करें', 64), ('भारत', 58)]

# %%
ranks_hi = np.arange(1, len(most_common_hi) + 1)
frequencies_hi = np.array([freq for word, freq in most_common_hi])

# %%
plt.figure(figsize=(8,6))
plt.loglog(ranks_hi, frequencies_hi, marker=".")
plt.xlabel("Rank")
plt.ylabel("Frequency")
plt.title("Zipf’s Law Verification (Hindi)")
plt.grid(True)
plt.show()

# %% [markdown]
# # **Telugu**

# %%
url = "https://www.gutenberg.org/cache/epub/40687/pg40687-images.html"
text_te = requests.get(url).text

# %%
words_te = re.findall(r"[\u0C00-\u0C7F]+", text_te)

print(words_te[:50])
# Out:
# ['కొల్లాయి', 'గట్టితే', 'నేమి', 'కొల్లాయి', 'గట్టితే', 'నేమి', 'కొల్లాయి', 'గట్టితే', 'నేమి', 'కొల్లాయి', 'గట్టితే', 'నేమి', 'కొల్లాయి', 'గట్టితే', 'నేమి', 'కొల్లాయి', 'గట్టితే', 'నేమి', 'కొల్లాయి', 'గట్టితే', 'నేమి', 'ఆంధ్రప్రదేశ్', 'సాహిత్య', 'అకాడమీ', 'అవార్డు', 'పొందిన', 'నవల', 'మహీధర', 'రామమోహనరావు', 'నవోదయ', 'పబ్లిషర్స్', 'కారల్', 'మార్క్స్', 'రోడ్డు', 'విజయవాడ', 'ఒకమాట', 'మార్చి', 'ఏప్రిల్', 'ఆనాడు', 'బెజవాడలో', 'అఖిలభారత', 'కాంగ్రెస్', 'కమిటీ', 'సమావేశం', 'జరిగింది', 'కాంగ్రెస్', 'జీవితంలో', 'ఆ', 'సమావేశానికి', 'ఎంతో']

# %%
word_counts_te = Counter(words_te)
most_common_te = word_counts_te.most_common()
print(most_common_te[:10])
# Out:
# [('ఆ', 1158), ('రామనాధం', 714), ('కాని', 484), ('ఆమె', 431), ('తన', 425), ('కూడా', 315), ('లేదు', 297), ('ఈ', 294), ('అని', 274), ('స్వరాజ్యం', 240)]

# %%
ranks_te = np.arange(1, len(most_common_te) + 1)
frequencies_te = np.array([freq for word, freq in most_common_te])
print(frequencies_te[:10])
# Out:
# [1158  714  484  431  425  315  297  294  274  240]

# %%
plt.figure(figsize=(8,6))
plt.loglog(ranks_te, frequencies_te, marker=".")
plt.xlabel("Rank")
plt.ylabel("Frequency")
plt.title("Zipf’s Law Verification (Telugu)")
plt.grid(True)
plt.show()
